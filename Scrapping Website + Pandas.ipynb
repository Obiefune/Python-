# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_Canada'

# %%
pages = requests.get(url)

# %%
BS_html = BeautifulSoup(pages.text, 'html')

# %%
#print(BS_html.prettify())

# %%
 table = BS_html.find_all('table')[2]

# %%
#print(table)

# %%
 fg_titles = table.find_all('th')

# %%
world_table_title_ca = [title.text.strip() for title in fg_titles]

#print(world_table_title_ca)

# %%
import pandas as pd

df = pd.DataFrame(columns = world_table_title_ca)

df
# Out:
# Empty DataFrame
# Columns: [Rank, Forbes 2000 rank, Name, Headquarters, Revenue(billions US$), Profit(billions US$), Assets(billions US$), Value(billions US$), Industry]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    #print(individual_row_data)
    length = len(df)
    df.loc[length] = individual_row_data

df
# Out:
#     Rank Forbes 2000 rank                         Name Headquarters  \
# 0      1               41         Royal Bank of Canada     Montreal
# 1      2               46        Toronto-Dominion Bank      Toronto
# 2      3               87                   Scotiabank      Toronto
# 3      4              118  Brookfield Asset Management      Toronto
# 4      5              134             Bank of Montreal     Montreal
# ..   ...              ...                          ...          ...
# 107   52             1757       Constellation Software      Toronto
# 108   53             1805           Canadian Utilities      Calgary
# 109   54             1940    Laurentian Bank of Canada     Montreal
# 110   55             1975                     Goldcorp    Vancouver
# 111   56             1978                      CAPREIT      Toronto
#
#     Revenue(billions US$) Profit(billions US$) Assets(billions US$)  \
# 0                    46.3                  9.6              1,040.3
# ...

# %%
df.to_csv(r'C:\Users\Owner\OneDrive\Desktop\DATA ANALYSIS COURSE\Python\Companies.csv', index = False)
